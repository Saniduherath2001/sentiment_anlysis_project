# %%
import numpy as numpy

# %%
import json
with open("../artifacts/kaggle.json","r") as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'sannyofficial', 'key': 'e3fe77eca02f76591d77120abbfb3377'}

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in d:\my project\sentiment_anlysis_project\env\lib\site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: colorama in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.4)
# Requirement already satisfied: webencodings in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my project\sentiment_anlysis_project\env\lib\site-packages (from requests->kaggle) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME']= data['username']
os.environ['KAGGLE_KEY']= data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_daownload_files("dineshpiyasamara/sentiment-analysis-dataset", path = "../artifacts/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 api.dataset_daownload_files("dineshpiyasamara/sentiment-analysis-dataset", path = "../artifacts/")
#
# AttributeError: 'KaggleApi' object has no attribute 'dataset_daownload_files'

# %%
api.dataset_download_file(
    dataset="dineshpiyasamara/sentiment-analysis-dataset", 
    path="../artifacts/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 api.dataset_download_file(
#       2     dataset="dineshpiyasamara/sentiment-analysis-dataset",
#       3     path="../artifacts/")
#
# TypeError: KaggleApi.dataset_download_file() missing 1 required positional argument: 'file_name'

# %%
api.dataset_download_files(
    "dineshpiyasamara/sentiment-analysis-dataset",
    path="../artifacts/",
    unzip=True
)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset
